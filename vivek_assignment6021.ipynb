# %% [markdown]
# # Homework
# Data documentation: https://tidyr.tidyverse.org/reference/who.html
#
# Directions: Answer the three questions below. Create as many code/markdown blocks necessary to answer the questions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv('/content/who.csv')

# %%
df = df.drop(columns=['iso2', 'iso3'])
df.head()
# Out:
#        country  year  new_sp_m014  ...  newrel_f4554  newrel_f5564  newrel_f65
# 0  Afghanistan  1980          NaN  ...           NaN           NaN         NaN
# 1  Afghanistan  1981          NaN  ...           NaN           NaN         NaN
# 2  Afghanistan  1982          NaN  ...           NaN           NaN         NaN
# 3  Afghanistan  1983          NaN  ...           NaN           NaN         NaN
# 4  Afghanistan  1984          NaN  ...           NaN           NaN         NaN
#
# [5 rows x 58 columns]

# %% [markdown]
# #### Question 1. We need to know what's included in this data.
# - How many countries are present?
# - What's the timespan of the data?
# - Does each country have a row for every year present?
# - Which countries are missing years?
# - How many rows have at least 1 non-null values across the columns 3-57?

# %%
#1
df['country'].nunique()
# Out:
# 219

# %%
#2

time_span= df['year'].max() - df['year'].min()
time_span
# Out:
# 33

# %%
#3Does each country have a row for every year present? 
df1 = pd.DataFrame()
df1 = df.groupby('country')['year'].count().reset_index()
df1.head(50)
# Out:
#                               country  year
# 0                         Afghanistan    34
# 1                             Albania    34
# 2                             Algeria    34
# 3                      American Samoa    34
# 4                             Andorra    34
# 5                              Angola    34
# 6                            Anguilla    34
# 7                 Antigua and Barbuda    34
# 8                           Argentina    34
# 9                             Armenia    34
# 10                              Aruba    34
# 11                          Australia    34
# 12                            Austria    34
# 13                         Azerbaijan    34
# 14                            Bahamas    34
# 15                            Bahrain    34
# 16                         Bangladesh    34
# 17                           Barbados    34
# 18                            Belarus    34
# 19                            Belgium    34
# 20                             Belize    34
# 21                              Benin    34
# 22                            Bermuda    34
# 23                             Bhutan    34
# 24   Bolivia (Plurinational State of)    34
# 25  Bonaire, Saint Eustatius and Saba     4
# 26             Bosnia and Herzegovina    34
# 27                           Botswana    34
# 28                             Brazil    34
# 29             British Virgin Islands    34
# 30                  Brunei Darussalam    34
# 31                           Bulgaria    34
# 32                       Burkina Faso    34
# 33                            Burundi    34
# 34                         Cabo Verde    34
# 35                           Cambodia    34
# 36                           Cameroon    34
# 37                             Canada    34
# 38                     Cayman Islands    34
# 39           Central African Republic    34
# 40                               Chad    34
# 41                              Chile    34
# 42                              China    34
# 43               China, Hong Kong SAR    34
# 44                   China, Macao SAR    34
# 45                           Colombia    34
# 46                            Comoros    34
# 47                              Congo    34
# 48                       Cook Islands    34
# 49                         Costa Rica    34

# %%
#4Which countries are missing years? 
df1['countries_missing_year'] = df1['year'].apply(lambda x: 0 if x==34 else 1)
df1.head(50)
# Out:
#                               country  year  countries_missing_year
# 0                         Afghanistan    34                       0
# 1                             Albania    34                       0
# 2                             Algeria    34                       0
# 3                      American Samoa    34                       0
# 4                             Andorra    34                       0
# 5                              Angola    34                       0
# 6                            Anguilla    34                       0
# 7                 Antigua and Barbuda    34                       0
# 8                           Argentina    34                       0
# 9                             Armenia    34                       0
# 10                              Aruba    34                       0
# 11                          Australia    34                       0
# 12                            Austria    34                       0
# 13                         Azerbaijan    34                       0
# 14                            Bahamas    34                       0
# 15                            Bahrain    34                       0
# 16                         Bangladesh    34                       0
# 17                           Barbados    34                       0
# 18                            Belarus    34                       0
# 19                            Belgium    34                       0
# 20                             Belize    34                       0
# 21                              Benin    34                       0
# 22                            Bermuda    34                       0
# 23                             Bhutan    34                       0
# 24   Bolivia (Plurinational State of)    34                       0
# 25  Bonaire, Saint Eustatius and Saba     4                       1
# 26             Bosnia and Herzegovina    34                       0
# 27                           Botswana    34                       0
# 28                             Brazil    34                       0
# 29             British Virgin Islands    34                       0
# 30                  Brunei Darussalam    34                       0
# 31                           Bulgaria    34                       0
# 32                       Burkina Faso    34                       0
# 33                            Burundi    34                       0
# 34                         Cabo Verde    34                       0
# 35                           Cambodia    34                       0
# 36                           Cameroon    34                       0
# 37                             Canada    34                       0
# 38                     Cayman Islands    34                       0
# 39           Central African Republic    34                       0
# 40                               Chad    34                       0
# 41                              Chile    34                       0
# 42                              China    34                       0
# 43               China, Hong Kong SAR    34                       0
# 44                   China, Macao SAR    34                       0
# 45                           Colombia    34                       0
# 46                            Comoros    34                       0
# 47                              Congo    34                       0
# 48                       Cook Islands    34                       0
# 49                         Costa Rica    34                       0

# %%
#5 How many rows have at least 1 non-null values across the columns 3-57?

df[df.columns[df.notna().any()]].notna().sum()
# Out:
# country         7240
# year            7240
# new_sp_m014     3173
# new_sp_m1524    3209
# new_sp_m2534    3206
# new_sp_m3544    3219
# new_sp_m4554    3223
# new_sp_m5564    3218
# new_sp_m65      3209
# new_sp_f014     3174
# new_sp_f1524    3194
# new_sp_f2534    3200
# new_sp_f3544    3199
# new_sp_f4554    3204
# new_sp_f5564    3195
# new_sp_f65      3197
# new_sn_m014     1045
# new_sn_m1524    1030
# new_sn_m2534    1022
# new_sn_m3544    1025
# new_sn_m4554    1027
# new_sn_m5564    1021
# new_sn_m65      1020
# new_sn_f014     1040
# new_sn_f1524    1022
# new_sn_f2534    1016
# new_sn_f3544    1020
# new_sn_f4554    1018
# new_sn_f5564    1017
# new_sn_f65      1019
# new_ep_m014     1038
# new_ep_m1524    1026
# new_ep_m2534    1020
# new_ep_m3544    1024
# new_ep_m4554    1020
# new_ep_m5564    1015
# new_ep_m65      1018
# new_ep_f014     1032
# new_ep_f1524    1021
# new_ep_f2534    1021
# new_ep_f3544    1021
# new_ep_f4554    1017
# new_ep_f5564    1017
# new_ep_f65      1014
# newrel_m014      190
# newrel_m1524     182
# newrel_m2534     183
# newrel_m3544     184
# newrel_m4554     184
# newrel_m5564     185
# newrel_m65       182
# newrel_f014      190
# newrel_f1524     184
# newrel_f2534     182
# newrel_f3544     183
# newrel_f4554     183
# newrel_f5564     183
# newrel_f65       185
# dtype: int64

# %%
sum([True for idx,row in df[2:].iterrows() if any(row.notna())])
# Out:
# 7238

# %% [markdown]
# #### Question 2: Wide data isn't usually helpful.
# Convert this to a long format with the following columns:
# 1. country
# 2. year
# 3. diagnosis method: mapping should be:
#
#   {'newsp':'Pulmonary Smear (+)'
#   ,'newsn':'Pulmonary Smear (-)'
#   ,'newep':'Extrapulmonary'
#   ,'newrel':'Relapse'}
#
#
# 4. gender: male or female.
# 5. age: lower_age - higher_age, e.g., 0-14
# 6. number of cases

# %%
df
# Out:
#           country  year  new_sp_m014  ...  newrel_f4554  newrel_f5564  newrel_f65
# 0     Afghanistan  1980          NaN  ...           NaN           NaN         NaN
# 1     Afghanistan  1981          NaN  ...           NaN           NaN         NaN
# 2     Afghanistan  1982          NaN  ...           NaN           NaN         NaN
# 3     Afghanistan  1983          NaN  ...           NaN           NaN         NaN
# 4     Afghanistan  1984          NaN  ...           NaN           NaN         NaN
# ...           ...   ...          ...  ...           ...           ...         ...
# 7235     Zimbabwe  2009        125.0  ...           NaN           NaN         NaN
# 7236     Zimbabwe  2010        150.0  ...           NaN           NaN         NaN
# 7237     Zimbabwe  2011        152.0  ...           NaN           NaN         NaN
# 7238     Zimbabwe  2012        120.0  ...           NaN           NaN         NaN
# 7239     Zimbabwe  2013          NaN  ...        1453.0         811.0       725.0
#
# [7240 rows x 58 columns]

# %%
dfLong = (
    df.melt(id_vars=['year','country'],var_name='newage', value_name='Pop')
)

dfLong.head()
# Out:
#    year      country       newage  Pop
# 0  1980  Afghanistan  new_sp_m014  NaN
# 1  1981  Afghanistan  new_sp_m014  NaN
# 2  1982  Afghanistan  new_sp_m014  NaN
# 3  1983  Afghanistan  new_sp_m014  NaN
# 4  1984  Afghanistan  new_sp_m014  NaN

# %%
dfLong[['diagnosismethod','Gend']]=dfLong['newage'].str.rsplit('_',n=1, expand= True)
dfLong = dfLong.drop(columns=['newage'])
dfLong.head()
# Out:
#    year      country  Pop diagnosismethod  Gend
# 0  1980  Afghanistan  NaN          new_sp  m014
# 1  1981  Afghanistan  NaN          new_sp  m014
# 2  1982  Afghanistan  NaN          new_sp  m014
# 3  1983  Afghanistan  NaN          new_sp  m014
# 4  1984  Afghanistan  NaN          new_sp  m014

# %%
dfLong['Age'] = dfLong['Gend'].str[1:]
dfLong.head()
# Out:
#    year      country  Pop diagnosismethod  Gend  Age
# 0  1980  Afghanistan  NaN          new_sp  m014  014
# 1  1981  Afghanistan  NaN          new_sp  m014  014
# 2  1982  Afghanistan  NaN          new_sp  m014  014
# 3  1983  Afghanistan  NaN          new_sp  m014  014
# 4  1984  Afghanistan  NaN          new_sp  m014  014

# %%
dfLong['Gender'] = dfLong['Gend'].str[0]
dfLong.head()
# Out:
#    year      country  Pop diagnosismethod  Gend  Age Gender
# 0  1980  Afghanistan  NaN          new_sp  m014  014      m
# 1  1981  Afghanistan  NaN          new_sp  m014  014      m
# 2  1982  Afghanistan  NaN          new_sp  m014  014      m
# 3  1983  Afghanistan  NaN          new_sp  m014  014      m
# 4  1984  Afghanistan  NaN          new_sp  m014  014      m

# %%
AgeGroup = {'014': '0-14', '1524': '15-24', '2534': '25-34', '3544':'35-44', '4554':'45-54','5564':'55-64','65':'65+'}
dfLong['Age'] = dfLong['Age'].map(AgeGroup)
dfLong.head()
# Out:
#    year      country  Pop diagnosismethod  Gend   Age Gender
# 0  1980  Afghanistan  NaN          new_sp  m014  0-14      m
# 1  1981  Afghanistan  NaN          new_sp  m014  0-14      m
# 2  1982  Afghanistan  NaN          new_sp  m014  0-14      m
# 3  1983  Afghanistan  NaN          new_sp  m014  0-14      m
# 4  1984  Afghanistan  NaN          new_sp  m014  0-14      m

# %% [raw]
# #### Question 3: Create a graph that shows when countries started to report TB cases.

# %%
#### Question 3: Create a graph that shows when countries started to report TB cases.

# %%
sns.jointplot(x='year',y='Pop',data=dfLong)
